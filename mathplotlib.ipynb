# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
df=pd.read_csv("/kaggle/input/school-tution-dataset/Tuition_Assistance_20240525.csv")

# %%
df
# Out:
#                    Department                                Major  \
# 0                      Police                Business/Admin./Mgmt.
# 1                      Police                Business/Admin./Mgmt.
# 2                      Police                Business/Admin./Mgmt.
# 3     Health & Human Services                Business/Admin./Mgmt.
# 4     Health & Human Services                          Other/Misc.
# ...                       ...                                  ...
# 4363                   Police                    Political Science
# 4364     Fire/Rescue Services                                  NaN
# 4365           Liquor Control               Information Technology
# 4366                   Police                          Other/Misc.
# 4367           Transportation  Civil and Environmental Engineering
#
#                         Degree                               School  \
# 0                           AA  Montgomery College Rockville Campus
# ...

# %%
df.columns
# Out:
# Index(['Department', 'Major', 'Degree', 'School', 'Course Title',
#        'Course Description', 'Cost'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Department              0
# Major                 485
# Degree                  0
# School                  0
# Course Title            0
# Course Description    197
# Cost                    0
# dtype: int64

# %%
df.drop(['Major','Course Description'] , axis=1 , inplace=True)

# %%
df
# Out:
#                    Department                    Degree  \
# 0                      Police                        AA
# 1                      Police                        AA
# 2                      Police                        AA
# 3     Health & Human Services  Masters (MA/MS/MPH/etc.)
# 4     Health & Human Services  Masters (MA/MS/MPH/etc.)
# ...                       ...                       ...
# 4363                   Police         Bachelors (BA/BS)
# 4364     Fire/Rescue Services                Non-Degree
# 4365           Liquor Control                        AA
# 4366                   Police                     Other
# 4367           Transportation         Bachelors (BA/BS)
#
#                                    School  \
# 0     Montgomery College Rockville Campus
# 1     Montgomery College Rockville Campus
# 2     Montgomery College Rockville Campus
# 3                  BOWIE STATE UNIVERSITY
# 4              Mount St Mary's University
# ...

# %%
df.isnull().sum()
# Out:
# Department      0
# Degree          0
# School          0
# Course Title    0
# Cost            0
# dtype: int64

# %%
df.dtypes
# Out:
# Department       object
# Degree           object
# School           object
# Course Title     object
# Cost            float64
# dtype: object

# %%
x=df[['Department','Degree','School','Course Title']]

# %%
y=df[['Cost']]

# %%
x.shape
# Out:
# (4368, 4)

# %%
y.shape
# Out:
# (4368, 1)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
print(type(x))
print(type(y))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>

# %%
df.describe()
# Out:
#               Cost
# count  4368.000000
# mean    786.263024
# std     533.319613
# min       0.000000
# 25%     366.000000
# 50%     700.000000
# 75%    1015.000000
# max    2300.000000

# %%
df['School'].unique()
# Out:
# array(['Montgomery College Rockville Campus', 'BOWIE STATE UNIVERSITY',
#        "Mount St Mary's University",
#        'University of Maryland - University College',
#        "PRINCE GEORGE'S COMMUNITY COLLEGE",
#        'University of Maryland - Baltimore',
#        'NATIONAL ASSOCIATION OF HOUSING AND REDEVELOPMENT OFFICIALS',
#        'FREDERICK COMMUNITY COLLEGE',
#        'University of Maryland - College Park',
#        'GEORGE WASHINGTON UNIVERSITY', 'George Washington University',
#        'MONTGOMERY COMMUNITY COLLEGE', 'Weber State University',
#        'CAPELLA UNIVERSITY', 'STRAYER UNIVERSITY', 'HOWARD UNIVERSITY',
#        'Waldorf College', 'BOSTON UNIVERSITY',
#        'American College of Physicians (ACP)', 'ARGOSY UNIVERSITY',
#        'UNIVERSITY OF DC', 'COLUMBIA SOUTHERN UNIVERSITY',
#        'CAPITOL COLLEGE', 'UNIVERSITY OF BALTIMORE',
#        'Robert Morris University', 'UNIVERSITY OF PHOENIX',
# ...

# %%
df.duplicated().sum()
# Out:
# 163

# %%
df.count()
# Out:
# Department      4368
# Degree          4368
# School          4368
# Course Title    4368
# Cost            4368
# dtype: int64

# %%
df=df.drop_duplicates()

# %%
df.head()
# Out:
#                 Department                    Degree  \
# 0                   Police                        AA
# 1                   Police                        AA
# 2                   Police                        AA
# 3  Health & Human Services  Masters (MA/MS/MPH/etc.)
# 4  Health & Human Services  Masters (MA/MS/MPH/etc.)
#
#                                 School  \
# 0  Montgomery College Rockville Campus
# 1  Montgomery College Rockville Campus
# 2  Montgomery College Rockville Campus
# 3               BOWIE STATE UNIVERSITY
# 4           Mount St Mary's University
#
#                                  Course Title    Cost
# 0                    INTRODUCTION TO BUSINESS   392.0
# 1                                      MA 160   392.0
# 2                     INTRO TO AMERICAN MUSIC   392.0
# 3                      PUBLIC POLICY ANALYSIS  1062.0
# 4  MHA 500 CONTEMPORARY ISSUES IN HEALTH CARE  1569.0

# %%
df['School'].duplicated().sum()
# Out:
# 3823

# %%
x=np.resize(x,)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 x=np.resize(x,)
#
# TypeError: resize() missing 1 required positional argument: 'new_shape'

# %%
x=df['Cost']
y=df['Department']

# %% [markdown]
# ***MATPLOTLIB****

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(x,y)
plt.xlabel("Cost")
plt.ylabel("Department")
plt.title("Scatter_Plot")

# %%
plt.plot(x,y)

# %%
df.head()

# %%
x1=df['Cost']
y1=df['Degree']

# %%
plt.bar(x1,y1 ,color='pink' ,align='edge',width=10,edgecolor="black",lw=10)

# %%
plt.hist(x1 , bins=7)

# %%
plt.hist(x1 , bins=7 ,cumulative=True)

# %%
x2=pd.get_dummies(df['Degree'])

# %%
x2

# %%
x2.shape

# %%
plt.pie(x2)

# %%
plt.boxplot(x1)

# %%
data1=[10,20,30,40,50]
data2=[50,40,30,20,10]

# %%
plt.plot(data1)
plt.plot(data2)
plt.legend(['data1'])

# %%
plt.pie(data1 , labels=None)
plt.legend(labels=['sample'])

# %%
plt.figure(1)
plt.plot(data1,data2)


plt.figure(2)
plt.scatter(data1,data2)
