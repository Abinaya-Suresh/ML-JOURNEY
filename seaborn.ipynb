# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("/kaggle/input/pizza-sales/A_year_of_pizza_sales_from_a_pizza_place_872_68.csv")

# %%
df
# Out:
#        Unnamed: 0      X           id        date      time         name size  \
# 0               1      1  2015-000001  2015-01-01  11:38:36     hawaiian    M
# 1               2      2  2015-000002  2015-01-01  11:57:40  classic_dlx    M
# 2               3      3  2015-000002  2015-01-01  11:57:40     mexicana    M
# 3               4      4  2015-000002  2015-01-01  11:57:40     thai_ckn    L
# 4               5      5  2015-000002  2015-01-01  11:57:40  five_cheese    L
# ...           ...    ...          ...         ...       ...          ...  ...
# 49569       49570  49570  2015-021348  2015-12-31  21:23:10  four_cheese    L
# 49570       49571  49571  2015-021348  2015-12-31  21:23:10   napolitana    S
# 49571       49572  49572  2015-021348  2015-12-31  21:23:10  ckn_alfredo    M
# 49572       49573  49573  2015-021349  2015-12-31  22:09:54     mexicana    L
# 49573       49574  49574  2015-021350  2015-12-31  23:02:05      bbq_ckn    S
#
#           type  price
# ...

# %%
df.isnull().sum()

# %%
df.duplicated().sum()

# %%
df.columns

# %%
df.info()

# %%
df.describe()

# %%
import seaborn as sns

# %%
sns.scatterplot(x="X", y="price", data=df,hue="type")
# Out:
# <Axes: xlabel='X', ylabel='price'>

# %%
sns.histplot(df["X"],kde=True , bins=15)#kde -lining ,its line distplot which is nothing but distribution
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='X', ylabel='Count'>

# %%
sns.displot(df["price"],kde=True , bins=15)
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.barplot(x="type",y="price",data=df)
# Out:
# <Axes: xlabel='type', ylabel='price'>

# %%
sns.boxplot(x="type",y="price" , data=df ,hue="type",palette="YlGnBu") #palette-color
# Out:
# <Axes: xlabel='type', ylabel='price'>

# %%
sns.stripplot(x="type",y="price" , data=df ,hue="size" )
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: xlabel='type', ylabel='price'>

# %%
sns.stripplot(x="type",y="price" , data=df ,hue="size" , dodge=True)#dodgr-is used to seperate the different types of relations
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='type', ylabel='price'>

# %%
#jointplot=scatterplot and distributionplot
sns.jointplot(x="X",y="price" , data=df )
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.jointplot(x="X",y="price" , data=df ,kind="reg")
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.jointplot(x="X",y="price" , data=df ,kind="hex")
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.pairplot(df.select_dtypes(['number']))
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.relplot(x="X",y="price",data=df)

# %%
sns.heatmap(df.select_dtypes(['number']).corr(),cmap="icefire")
# Out:
# <Axes: >
